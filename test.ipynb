# %%
from tokenizers.bpe import BpeTokenizer
import csv

# %%
texts = []
with open('data/chatbot_kor/chatbot.csv', 'r', encoding='utf-8') as f:
    data = csv.reader(f)
    first_row = next(data)
    for row in data:
        texts.append(row[0])
        texts.append(row[1])
len(texts)
# Out:
# 23646

# %%
t = BpeTokenizer()

# %%
t.train(texts)
# Out:
# Counting pairs.. 2991/86084: : 2743it [00:00, 3464.11it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Counting pairs.. 14124/86084: : 13825it [00:04, 3425.46it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Counting pairs.. 26196/86084: : 25802it [00:07, 4047.14it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...

# %%
len(t.index_to_voca)
