# %%
from tokenizers.bpe import BpeTokenizer
import csv

# %%
texts = []
with open('data/chatbot_kor/chatbot.csv', 'r', encoding='utf-8') as f:
    data = csv.reader(f)
    first_row = next(data)
    for row in data:
        texts.append(row[0])
        texts.append(row[1])
len(texts)
# Out:
# 23646

# %%
t = BpeTokenizer()

# %%
t.train(texts)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
len(t.index_to_voca)
